# %% [markdown]
# # Wildfire Detection False-Positive Rejection and Fire Risk
#
# Background: I'm working at OroraTech GmbH (https://ororatech.com/), a young Munich-based company providing satellite-based wildfire detection and monitoring services.
#
# `Valentin Dornauer <valentin@unimplemented.org>`
#
# ## Aggregate confirmed fires (training data)
#
# The EFFIS project provides a manually curated list of actual wildfires, along with coordinates and timespans. These fires are used as "true positives" for the ML model. They are provided as KML (XML-based format). These attributes are extracted and saved into the `confirmed=[]` list.
#
# https://effis.jrc.ec.europa.eu/applications/fire-news/

# %%
# !pip3 install fastkml requests
from fastkml import kml
import requests
# Out:
# Requirement already satisfied: fastkml in ./.local/lib/python3.7/site-packages (0.11)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (2.21.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from fastkml) (2.8.0)
# Requirement already satisfied: pygeoif in ./.local/lib/python3.7/site-packages (from fastkml) (0.7)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil->fastkml) (1.12.0)
# Package `lxml` missing. Pretty print will be disabled

# %%
k = kml.KML()
ret = k.from_string(requests.get("z").text.encode('utf-8'))
root = list(k.features())
folder = list(root[0].features())

# %%
import datetime
confirmed = []
for f in folder[0].features():
  #print(f)
  start = False
  end = False
  for e in f.extended_data.elements[0].data:
    if e["name"] == "StartDate":
      start = datetime.datetime.strptime(e["value"], '%d/%m/%Y')
    if e["name"] == "EndDate":
      end = datetime.datetime.strptime(e["value"], '%d/%m/%Y')
  duration = (end-start).days + 1
  #print("lat=%f lon=%f start=%s end=%s durations=%dd" % (f.geometry.y, f.geometry.x, start, end, duration))
  confirmed.append({
      "lat": f.geometry.y,
      "lon": f.geometry.x,
      "start": start,
      "duration": duration,
      "end": end
  })
confirmed[:2]
# Out:
# [{'lat': 40.1548666,
#   'lon': 15.62756688,
#   'start': datetime.datetime(2018, 11, 26, 0, 0),
#   'duration': 2,
#   'end': datetime.datetime(2018, 11, 27, 0, 0)},
#  {'lat': 40.05362301,
#   'lon': 15.35781179,
#   'start': datetime.datetime(2018, 11, 22, 0, 0),
#   'duration': 1,
#   'end': datetime.datetime(2018, 11, 22, 0, 0)}]

# %% [markdown]
# # Import FIRMS events
#
# NASA provides a hot spot product from three of their satellites (MODIS-AQUA, MODIS-TERRA and Suomi-NPP). These satellites carry infrared-based sensors which can be used to detect wildfires. These hotspots are provided as CSV on the NASA website.
#
# To limit the amount of data, currently only data for 2018 and the EU region is used.
#
# https://firms.modaps.eosdis.nasa.gov/download/
#
# Area of Interest: `POLYGON((35.29705 33.49591,20.76892 33.68388,13.33854 34.4395,5.66475 37.24806,-3.33463 35.42468,-13.6752 35.77723,-15.50407 46.13137,-14.90754 54.9731,-7.92903 63.7695,6.86012 67.51096,15.81302 71.28015,27.57649 72.13655,38.83294 70.43848,48.20104 70.15378,57.59657 69.997,51.79583 37.30234,35.29705 33.49591))`

# %%
from zipfile import ZipFile
from io import StringIO
from io import BytesIO
from urllib.request import urlopen

resp = urlopen('https://unimplemented.org/~valentin/DL_FIRE_M6_96138.zip')
zipfile = ZipFile(BytesIO(resp.read()))
zipfile.namelist()
# Out:
# ['fire_archive_M6_96138.json', 'Readme.txt']

# %%
import json
# takes around 4GB ram
modis_fires = json.loads(zipfile.read("fire_archive_M6_96138.json"))
zipfile.close()
# free some
zipfile = None
resp = None

# %%
# same for VIIRS fires (a lot more because of higher spatial resolution)

resp = urlopen('https://unimplemented.org/~valentin/DL_FIRE_V1_96139.zip')
zipfile = ZipFile(BytesIO(resp.read()))
zipfile.namelist()
viirs_fires = json.loads(zipfile.read("fire_archive_V1_96139.json"))
zipfile.close()
zipfile = None
resp = None

unconfirmed = modis_fires + viirs_fires

# %%
import pandas as pd
df = pd.DataFrame(modis_fires + viirs_fires)
df
# Out:
#         latitude  longitude    acq_date acq_time instrument confidence  scan  \
# 0       42.71470   24.17460  2018-01-01     0026      MODIS         63  1.00
# 1       43.52590   -5.73610  2018-01-01     0205      MODIS         80  1.60
# 2       43.52410   -5.71690  2018-01-01     0205      MODIS         57  1.60
# 3       37.50640   22.41810  2018-01-01     1131      MODIS         75  1.10
# 4       37.64550   22.65040  2018-01-01     1131      MODIS         60  1.10
# ...          ...        ...         ...      ...        ...        ...   ...
# 632588  36.01836   43.68176  2018-12-31     2347      VIIRS          n  0.44
# 632589  35.99747   43.76006  2018-12-31     2347      VIIRS          n  0.45
# 632590  35.99618   43.76345  2018-12-31     2347      VIIRS          n  0.45
# 632591  35.63039   44.00753  2018-12-31     2347      VIIRS          n  0.47
# 632592  36.07984   43.64091  2018-12-31     2347      VIIRS          n  0.44
#
#        satellite  track type  brightness daynight   frp  bright_t31 version  \
# 0           Aqua   1.00    2       305.0        N  12.1       271.2     6.2
# 1           Aqua   1.20    2       310.4        N  26.3       280.2     6.2
# 2           Aqua   1.20    2       303.8        N  18.1       279.8     6.2
# 3           Aqua   1.00    0       314.2        D  15.6       286.5     6.2
# 4           Aqua   1.00    0       304.9        D   8.0       288.6     6.2
# ...          ...    ...  ...         ...      ...   ...         ...     ...
# 632588         N   0.63    0         NaN      NaN   2.0         NaN       1
# 632589         N   0.63    0         NaN      NaN   4.6         NaN       1
# 632590         N   0.63    0         NaN      NaN   6.4         NaN       1
# 632591         N   0.64    2         NaN      NaN  15.4         NaN       1
# 632592         N   0.62    0         NaN      NaN   0.9         NaN       1
#
#         bright_ti4  bright_ti5
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 632588       310.6       273.5
# 632589       317.8       277.0
# 632590       354.3       277.8
# 632591       343.7       280.5
# 632592       309.5       272.0
#
# [632593 rows x 17 columns]

# %%
df.describe()
# Out:
#             latitude      longitude           scan          track  \
# count  632593.000000  632593.000000  632593.000000  632593.000000
# mean       47.900935      30.884054       0.656905       0.614947
# std         6.650053      15.340606       0.524368       0.306590
# min        33.516620     -10.446820       0.320000       0.360000
# 25%        43.636100      21.176940       0.400000       0.390000
# 50%        48.381750      34.953700       0.470000       0.500000
# 75%        52.229500      42.482180       0.600000       0.680000
# max        71.316510      57.310520       4.800000       2.000000
#
#           brightness            frp     bright_t31     bright_ti4  \
# count  116338.000000  632593.000000  116338.000000  516255.000000
# mean      317.238760       9.568181     295.342548     325.846379
# std        14.110712      26.135747       8.738461      19.319324
# min       300.000000       0.000000     264.700000     208.000000
# 25%       307.400000       1.800000     290.000000     306.500000
# 50%       314.100000       4.100000     295.000000     329.900000
# 75%       323.400000       9.000000     300.600000     339.500000
# max       500.000000    3010.900000     346.800000     367.000000
#
#           bright_ti5
# count  516255.000000
# mean      290.933383
# std        11.133298
# min       230.500000
# 25%       283.600000
# 50%       290.400000
# 75%       298.300000
# max       380.000000

# %% [markdown]
# # Augment FIRMS data with environmental data
#
# Environmental data like air temperature, humidity, soil moisture, wind speed and air pressure play a very important role in wildfire spread and outbreak. All of this data is available from the ECMWF Climate Data Store, specifically the ERA-5 dataset.
#
# Another important parameter is the landuse class. For example, it's more likely that a fire breaks out in a forest area, and very unlikely that a wildfire occures in a city. The landuse data is taken from the ESA CCI archive and can be browsed here: https://maps.elie.ucl.ac.be/CCI/viewer/
#
# These parameters will later be used as parameters in the ML model.

# %%
def log_progress(sequence, every=None, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )

# %%
import os
import xarray as xr
import numpy as np
import math
import datetime

open_files = {}
generic_files = {}
def get_soil_moisture(lat, lon, date):
  global open_files
  soil_path = "/mnt/satdata/cci/valli/2018/"
  soil_basename = "ESACCI-SOILMOISTURE-L3S-SSMV-COMBINED-%s000000-fv04.5.nc"
  sm = float('nan')
  current = None
  tries = 0
  last_file = None
  while math.isnan(sm):
    if not current:
      current = date
    else:
      #print("No match on %s" % current.strftime("%Y%m%d"))
      current = current - datetime.timedelta(days=1)

    this_file = soil_path + soil_basename % (current.strftime("%Y%m%d"))
    # don't reopen same file for performance reasons
    #if last_file != this_file:
    #  if last_file:
    #    ds.close()
    #  try:
    #    ds = xr.open_dataset(this_file)
    #  except FileNotFoundError:
    #    print("file not found")
    #    print(this_file)
    #    return float('nan')
    #  last_file = this_file
    if this_file not in open_files:
        try:
          open_files[this_file] = xr.open_dataset(this_file)
        except FileNotFoundError:
          #print("file not found")
          return float('nan')
    ds = open_files[this_file]
    sm = float(ds.sel(lon=lon, lat=lat, method='nearest').sm[0])
    
    tries += 1
    if tries > 10:
      #print("no match found for %f,%f" % (lat, lon))
      return float('nan')
  return sm

def get_generic(lat, lon, date, source):
  global generic_files
  if not source in generic_files:
    generic_files[source] = xr.open_dataset(source)
  return generic_files[source].sel(longitude=lon, latitude=lat, method='nearest', time=date)

def get_2m_temp(lat, lon, date):
  return float(get_generic(lat, lon, date, "/mnt/satdata/cds_temperature_2018/adaptor.mars.internal-1578651611.7415073-20673-14-3fc2d3df-53ae-4bf7-ac9d-5a5516e04e23.nc").t2m) - 273.15

def get_pressure(lat, lon, date):
  return float(get_generic(lat, lon, date, "/mnt/satdata/cds_pressure/adaptor.mars.internal-1578849827.0299203-14292-21-da50a985-de94-492e-82d3-53ef3c498cf6.nc").sp)

def get_wind_u(lat, lon, date):
  return float(get_generic(lat, lon, date, "/mnt/satdata/cds_wind_2018/adaptor.mars.internal-1578876852.5801854-24131-3-b80cffe0-c0bf-4a4a-a991-6c59dba38c61.nc").u10)

def get_wind_v(lat, lon, date):
  return float(get_generic(lat, lon, date, "/mnt/satdata/cds_wind_2018/adaptor.mars.internal-1578876864.367913-28293-9-e32d8be9-0269-44bf-b82b-a161e5948188.nc").v10)

def get_dewpoint(lat, lon, date):
  return float(get_generic(lat, lon, date, "/mnt/satdata/cds_dewpoint/adaptor.mars.internal-1578849582.491526-11988-17-03ffb1c2-97ed-4e6f-ace4-5be1e52d934c.nc").d2m)

def get_landuse(lat, lon):
  global generic_files
  source = "/mnt/satdata/cci/anon-ftp.ceda.ac.uk/neodc/esacci/land_cover/data/land_cover_maps/v2.0.7/ESACCI-LC-L4-LCCS-Map-300m-P1Y-2015-v2.0.7b.nc"
  if not source in generic_files:
    generic_files[source] = xr.open_dataset(source)
    
  flags = generic_files[source].sel(lon=lon, lat=lat, method='nearest').lccs_class.attrs["flag_values"]
  meanings = generic_files[source].sel(lon=lon, lat=lat, method='nearest').lccs_class.attrs["flag_meanings"].split(" ")
  lc = int(generic_files[source].sel(lon=lon, lat=lat, method='nearest').lccs_class)

  ret = None
  try:
    ret = meanings[np.where(flags == lc)[0][0]]
  except IndexError:
    ret = lc
  #print(generic_files[source].get(["flag_meanings"]))
  #return generic_files[source].sel(lon=lon, lat=lat, method='nearest').lccs_class.attrs["flag_meanings"].split(" ")
  return ret

#def get_2m_temp(lat, lon, date):
#  global temperature_file
#  if not temperature_file:
#    temperature_file = xr.open_dataset()
#  return float(temperature_file.sel(longitude=lon, latitude=lat, method='nearest', time=date).t2m) - 273.15

wind_u = []
wind_v = []
dewpoint = []
for fire in log_progress(unconfirmed, every=100):
  fire["x_temp"] = get_2m_temp(fire["latitude"], fire["longitude"], datetime.datetime.strptime(fire["acq_date"] + " " + fire["acq_time"], '%Y-%m-%d %H%M'))
  fire["x_pressure"] = get_pressure(fire["latitude"], fire["longitude"], datetime.datetime.strptime(fire["acq_date"] + " " + fire["acq_time"], '%Y-%m-%d %H%M'))
  fire["x_landuse"] = get_landuse(fire["latitude"], fire["longitude"])
  fire["x_soilmoisture"] = get_soil_moisture(fire["latitude"], fire["longitude"], datetime.datetime.strptime(fire["acq_date"], '%Y-%m-%d'))
  fire["x_windu"] = get_wind_u(fire["latitude"], fire["longitude"], datetime.datetime.strptime(fire["acq_date"], '%Y-%m-%d'))
  fire["x_windv"] = get_wind_v(fire["latitude"], fire["longitude"], datetime.datetime.strptime(fire["acq_date"], '%Y-%m-%d'))
  fire["x_dewpoint"] = get_dewpoint(fire["latitude"], fire["longitude"], datetime.datetime.strptime(fire["acq_date"], '%Y-%m-%d'))
# Out:
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Convert to pandas dataframe and save it to disk, because retrieving the envioronmental data takes ages (each environmental file is around 110GB).

# %%
import pandas as pd

c = pd.DataFrame(unconfirmed)
#c.insert(9, "x_wind_v", wind_v)
#c.insert(9, "x_wind_u", wind_u)
#c.insert(9, "x_dewpoint", dewpoint)
####c.to_pickle("confirmed_v2.pickle")
c.describe()

# %% [markdown]
# # Associate confirmations with actual fire events
#
# Currently, a very basic bounding box matching is used. Would be more efficient and accurate with an actual spatial search (like PostGIS), but this works fine for now.
#
# Currently matches fires in a 0.1 degree radius, which is around 7 to 11 km on European latitudes. https://en.wikipedia.org/wiki/Latitude#Length_of_a_degree_of_latitude

# %%
# matching of actual fires to confirmed ones.

confirmed_lst = []
for row in log_progress(df.itertuples(), every=100):
    found = False
    for fire in confirmed:
        valid_days = [(fire["start"] + datetime.timedelta(days=i)).strftime("%Y-%m-%d") for i in range(fire["duration"])]
        if not str(row.acq_date) in valid_days:
          continue
        if abs(row.latitude - fire["lat"]) <= 0.1 and abs(row.longitude - fire["lon"]) <= 0.1:
          found = True
          confirmed_lst.append(True)
          break
    if not found:
        confirmed_lst.append(False)
        
confirmed_lst

#matched = list(confirmed)
#confirmed_num = 0
#for fire in confirmed:
#  fire["events"] = []
#  #print(valid_days)
#  for firmsfire in viirs_fires:
#    if not firmsfire["acq_date"] in valid_days:
#      continue
#    if abs(firmsfire["latitude"] - fire["lat"]) <= 0.1 and abs(firmsfire["longitude"] - fire["lon"]) <= 0.1:
#      fire["events"].append(firmsfire)

  #if len(fire["events"]) > 0:
  #  print("%d fires for cluster %s" % (len(fire["events"]), valid_days))    
  
#  confirmed_num += len(fire["events"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7fc1d207b289> in <module>()
#       2
#       3 confirmed_lst = []
# ----> 4 for row in log_progress(df.itertuples(), every=100):
#       5     found = False
#       6     for fire in confirmed:
#
# NameError: name 'df' is not defined

# %%
#c.to_pickle("confirmed_v2.pickle")
c
# Out:
#         latitude  longitude    acq_date acq_time instrument confidence  scan  \
# 0       42.71470   24.17460  2018-01-01     0026      MODIS         63  1.00
# 1       43.52590   -5.73610  2018-01-01     0205      MODIS         80  1.60
# 2       43.52410   -5.71690  2018-01-01     0205      MODIS         57  1.60
# 3       37.50640   22.41810  2018-01-01     1131      MODIS         75  1.10
# 4       37.64550   22.65040  2018-01-01     1131      MODIS         60  1.10
# ...          ...        ...         ...      ...        ...        ...   ...
# 632588  36.01836   43.68176  2018-12-31     2347      VIIRS          n  0.44
# 632589  35.99747   43.76006  2018-12-31     2347      VIIRS          n  0.45
# 632590  35.99618   43.76345  2018-12-31     2347      VIIRS          n  0.45
# 632591  35.63039   44.00753  2018-12-31     2347      VIIRS          n  0.47
# 632592  36.07984   43.64091  2018-12-31     2347      VIIRS          n  0.44
#
#        satellite  track  x_confirmed  ...  daynight   frp  bright_t31 version  \
# 0           Aqua   1.00        False  ...         N  12.1       271.2     6.2
# 1           Aqua   1.20        False  ...         N  26.3       280.2     6.2
# 2           Aqua   1.20        False  ...         N  18.1       279.8     6.2
# 3           Aqua   1.00        False  ...         D  15.6       286.5     6.2
# 4           Aqua   1.00        False  ...         D   8.0       288.6     6.2
# ...          ...    ...          ...  ...       ...   ...         ...     ...
# 632588         N   0.63        False  ...       NaN   2.0         NaN       1
# 632589         N   0.63        False  ...       NaN   4.6         NaN       1
# 632590         N   0.63        False  ...       NaN   6.4         NaN       1
# 632591         N   0.64        False  ...       NaN  15.4         NaN       1
# 632592         N   0.62        False  ...       NaN   0.9         NaN       1
#
#            x_temp     x_pressure                             x_landuse  \
# 0        1.589868   91111.093750                                   190
# 1        7.623682  100632.546875                                   190
# 2        7.623682  100632.546875                                   190
# 3       11.630273   92420.023438                      cropland_rainfed
# 4       15.253351   99267.734375  cropland_rainfed_tree_or_shrub_cover
# ...           ...            ...                                   ...
# 632588   5.592432   98918.250000                                   200
# 632589   6.209619   98742.085938                                   200
# 632590   6.209619   98742.085938                                   200
# 632591   5.774194   99196.703125                                   200
# 632592   5.362756   99424.015625                                   200
#
#         x_soilmoisture bright_ti4  bright_ti5
# 0             0.298845        NaN         NaN
# 1                  NaN        NaN         NaN
# 2                  NaN        NaN         NaN
# 3                  NaN        NaN         NaN
# 4             0.261836        NaN         NaN
# ...                ...        ...         ...
# 632588        0.370599      310.6       273.5
# 632589        0.372238      317.8       277.0
# 632590        0.372238      354.3       277.8
# 632591        0.325685      343.7       280.5
# 632592        0.370599      309.5       272.0
#
# [632593 rows x 25 columns]

# %% [markdown]
# # Actual statistics part
#
# First attempt to use ML to make sense of the data. Goal: predict, whether or not a new fire event is actually a wildfire or not (false positive rejection).
#
# The total amount of confirmed fire detections is very low, sadly (around 1%), so it's questionable whether the remaining 99% are actually false positives. Luckily, NASA provides a confidence along with its detections (High, Normal, Low or a numeric value between 0 (unlikely) to 100 (very likely). So for the first try, we select two classes from the NASA data:
#
# - Confirmed fires, independently of their confidence value
# - "Fires" with very low confidence

# %%
import pandas as pd
import math
df = pd.read_pickle("confirmed_v2.pickle")
df['x_wind'] = df.apply(lambda row: (math.sqrt(row["x_wind_u"]**2 + row["x_wind_v"]**2)), axis=1)
df = df.drop(['scan', 'satellite', 'track', 'version', 'type', 'daynight', 'bright_t31', 'bright_ti4', 'bright_ti5', 'brightness', 'x_wind_v', 'x_wind_u'], axis=1)
df['x_landuse'] = df['x_landuse'].apply(str)
#df.describe()
df.head(3)
# Out:
#    latitude  longitude    acq_date acq_time instrument confidence  \
# 0   42.7147    24.1746  2018-01-01     0026      MODIS         63
# 1   43.5259    -5.7361  2018-01-01     0205      MODIS         80
# 2   43.5241    -5.7169  2018-01-01     0205      MODIS         57
#
#    x_confirmed  x_dewpoint   frp    x_temp     x_pressure x_landuse  \
# 0        False  269.399475  12.1  1.589868   91111.093750       190
# 1        False  278.833618  26.3  7.623682  100632.546875       190
# 2        False  278.833618  18.1  7.623682  100632.546875       190
#
#    x_soilmoisture    x_wind
# 0        0.298845  0.625623
# 1             NaN  5.790970
# 2             NaN  5.790970

# %% [markdown]
# ## Some graphs
#
# (I didn't have time yet to look through all (geo)pandas plots yet)

# %%
import matplotlib.pyplot as plt
#df[df.x_confirmed == True].plot.scatter(x="x_temp", y="x_soilmoisture")
df[df.x_confirmed == True].plot.scatter(x="x_wind", y="x_soilmoisture")

# %%
# remove all uncertain events, leave all confirmed in
#print(len(df))
#df = df[(df.confidence != 'l') | (df.x_confirmed == True)]
#df = df[(df.confidence != 'n') | (df.x_confirmed == True)]
#print(len(df))
df["confidence"] = df["confidence"].replace("l", '1')
df["confidence"] = df["confidence"].replace("n", '50')
df["confidence"] = df["confidence"].replace("h", '99').astype('int32')
#df = df[(df.confidence > 60) | (df.x_confirmed == True)]
#print(len(df))

print(len(df))
# remove all unconfirmed, HIGH confidence ones to leave only unconfirmed, low-confidence ones
df = df[(                (df.confidence < 10 )         ) | (df.x_confirmed == True)]
print(len(df))

#df = df[type(df.confidence) == "int" & df.confidence < '50']
# Out:
# 632593
# 27909

# %%
#c.plot.scatter(y="frp", x="x_temp")
#c[c.s]plot(y="frp", logy=True)
#c[c.instrument == "VIIRS"]
#c[c.instrument == "VIIRS"].frp.plot()
#c[c.instrument == "MODIS"].frp.plot()
#c[c.instrument == "VIIRS"].frp

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer, MinMaxScaler, RobustScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
print(len(df))
c = df.dropna()
print(len(c))

transform = make_column_transformer(
    (MinMaxScaler(), ['x_temp', 'x_pressure', 'x_soilmoisture', 'x_dewpoint', 'x_wind']),
    (OneHotEncoder(), ['x_landuse']),
)
# Out:
# 27909
# 22857

# %%
import numpy as np
X_train, X_test, y_train, y_test = train_test_split(c, c.x_confirmed, test_size=0.3)

from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
model = make_pipeline(
    transform,
    SVC(probability=True))
model.fit(X_train, y_train)
pred = model.predict(X_test)
print("SVC regression score: %f" % model.score(X_test, y_test))

print(classification_report(y_test, pred, target_names=['actually a fire', 'not sure']))
# Out:
# SVC regression score: 0.951298
#                  precision    recall  f1-score   support
#
# actually a fire       0.97      0.98      0.97      6406
#        not sure       0.66      0.54      0.59       452
#
#        accuracy                           0.95      6858
#       macro avg       0.81      0.76      0.78      6858
#    weighted avg       0.95      0.95      0.95      6858

# %% [markdown]
# TBH this looks like overfitting. 😅

# %%
f
# Out:
# Pipeline(memory=None,
#          steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('minmaxscaler',
#                                                   MinMaxScaler(copy=True,
#                                                                feature_range=(0,
#                                                                               1)),
#                                                   ['x_temp', 'x_pressure',
#                                                    'x_soilmoisture',
#                                                    'x_dewpoint', 'x_wind']),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(categories='auto',
#                                                                 drop=None,
#                                                                 dtype=<class 'numpy.float64'>,
#                                                                 handle_unknown='error',
#                                                                 sparse=True),
#                                                   ['x_landuse'])],
#                                    verbose=False)),
#                 ('svc',
#                  SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None,
#                      coef0=0.0, decision_function_shape='ovr', degree=3,
#                      gamma='scale', kernel='rbf', max_iter=-1, probability=True,
#                      random_state=None, shrinking=True, tol=0.001,
#                      verbose=False))],
#          verbose=False)

# %%
import datetime

def synth_fire(day, lat, lon):
  coords = [lon, lat]
  actual_day = 1 + day*2
  date_str = "2018-08-%02d 1500" % actual_day
  dt = datetime.datetime.strptime(date_str, '%Y-%m-%d %H%M')

  fire = {"latitude": lat, "longitude": lon, "acq_date": "", "acq_time": "", "instrument": "", "x_confirmed": False, "frp": "", "x_wind_u": 0, "x_wind_v": 0}
  fire["x_temp"] = get_2m_temp(coords[1], coords[0], dt)
  fire["x_pressure"] = get_pressure(coords[1], coords[0], dt)
  fire["x_landuse"] = str(get_landuse(coords[1], coords[0]))
  fire["x_soilmoisture"] = get_soil_moisture(coords[1], coords[0], dt)
  fire["x_dewpoint"] = get_dewpoint(coords[1], coords[0], dt)
  fire["x_wind_u"] = get_wind_u(coords[1], coords[0], dt)
  fire["x_wind_v"] = get_wind_v(coords[1], coords[0], dt)
  fire["x_wind"] = math.sqrt(fire["x_wind_u"]**2 + fire["x_wind_v"]**2)

  #print(fire)
  #wind_u.append(get_wind_u(fire["latitude"], fire["longitude"], datetime.datetime.strptime(fire["acq_date"], '%Y-%m-%d')))
  #wind_v.append(get_wind_v(fire["latitude"], fire["longitude"], datetime.datetime.strptime(fire["acq_date"], '%Y-%m-%d')))
  #dewpoint.append(get_dewpoint(fire["latitude"], fire["longitude"], datetime.datetime.strptime(fire["acq_date"], '%Y-%m-%d')))
  return fire

#f = []
multidays = {}
for day in log_progress(range(15)):
    for i in log_progress(range(100)):
        for j in range(100):
            multidays[day] = synth_fire(day, 55.0-(j*0.1), 5.0 + (i*0.1))

# %%
#fail = pd.DataFrame(f).reindex_like(c)
#fail = fail.drop(fail.index[900:])
#fail = fail[np.isfinite(fail['x_soilmoisture'])]
#fail = fail[np.isfinite(fail['x_pressure'])]
#fail = fail[np.isfinite(fail['x_temp'])]
#fail = fail[np.isfinite(fail['x_dewpoint'])]
#fail = fail[np.isfinite(fail['x_wind'])]
#len(fail)
fail = pd.DataFrame(f)
fail = fail[np.isfinite(fail['latitude'])]
#fail = fail.dropna(subset=['x_landuse'])
#print(len(fail))
fail = fail.reindex(columns=df.columns)
print(len(fail))

fail = fail[np.isfinite(fail['x_soilmoisture'])]
fail = fail[np.isfinite(fail['x_pressure'])]
fail = fail[np.isfinite(fail['x_temp'])]
fail = fail[np.isfinite(fail['x_dewpoint'])]
fail = fail[np.isfinite(fail['x_wind'])]
fail
# Out:
# 40000
#        latitude  longitude acq_date acq_time instrument  confidence  \
# 46        52.70       5.00                                      NaN
# 47        52.65       5.00                                      NaN
# 50        52.50       5.00                                      NaN
# 51        52.45       5.00                                      NaN
# 52        52.40       5.00                                      NaN
# ...         ...        ...      ...      ...        ...         ...
# 39995     45.25      14.95                                      NaN
# 39996     45.20      14.95                                      NaN
# 39997     45.15      14.95                                      NaN
# 39998     45.10      14.95                                      NaN
# 39999     45.05      14.95                                      NaN
#
#        x_confirmed  x_dewpoint frp     x_temp     x_pressure  \
# 46           False  283.199280      17.404443  102239.812500
# 47           False  283.199280      17.404443  102239.812500
# 50           False  283.314972      17.606165  102185.828125
# 51           False  283.314972      17.606165  102185.828125
# 52           False  283.365784      17.741998  102202.875000
# ...            ...         ...  ..        ...            ...
# 39995        False  284.669708      22.936975   91370.609375
# 39996        False  283.861755      23.074762   91182.132812
# 39997        False  283.861755      23.074762   91182.132812
# 39998        False  285.125366      25.098047   94091.695312
# 39999        False  285.125366      25.098047   94091.695312
#
#                                        x_landuse  x_soilmoisture    x_wind
# 46                                           130        0.332273  5.448339
# 47                                           130        0.332273  5.448339
# 50                     mosaic_natural_vegetation        0.332273  4.774651
# 51                                           130        0.300406  4.774651
# 52                                           130        0.300406  4.491834
# ...                                          ...             ...       ...
# 39995                                 tree_mixed        0.259076  0.339181
# 39996                                 tree_mixed        0.199880  0.509923
# 39997                                 tree_mixed        0.199880  0.509923
# 39998  tree_broadleaved_deciduous_closed_to_open        0.199880  0.789099
# 39999                                 tree_mixed        0.199880  0.789099
#
# [34511 rows x 14 columns]

# %%
#fail[fail.x_landuse == ""]
#fail[np.isnan(fail.x_landuse)]
valid = fail.x_landuse.unique()
#fail.x_landuse.unique()
fail = fail.dropna(subset=['x_landuse'])

# %%
fail
# Out:
#        latitude  longitude acq_date acq_time instrument  confidence  \
# 46        52.70       5.00                                      NaN
# 47        52.65       5.00                                      NaN
# 50        52.50       5.00                                      NaN
# 51        52.45       5.00                                      NaN
# 52        52.40       5.00                                      NaN
# ...         ...        ...      ...      ...        ...         ...
# 39995     45.25      14.95                                      NaN
# 39996     45.20      14.95                                      NaN
# 39997     45.15      14.95                                      NaN
# 39998     45.10      14.95                                      NaN
# 39999     45.05      14.95                                      NaN
#
#        x_confirmed  x_dewpoint frp     x_temp     x_pressure  \
# 46           False  283.199280      17.404443  102239.812500
# 47           False  283.199280      17.404443  102239.812500
# 50           False  283.314972      17.606165  102185.828125
# 51           False  283.314972      17.606165  102185.828125
# 52           False  283.365784      17.741998  102202.875000
# ...            ...         ...  ..        ...            ...
# 39995        False  284.669708      22.936975   91370.609375
# 39996        False  283.861755      23.074762   91182.132812
# 39997        False  283.861755      23.074762   91182.132812
# 39998        False  285.125366      25.098047   94091.695312
# 39999        False  285.125366      25.098047   94091.695312
#
#                                        x_landuse  x_soilmoisture    x_wind
# 46                                           130        0.332273  5.448339
# 47                                           130        0.332273  5.448339
# 50                     mosaic_natural_vegetation        0.332273  4.774651
# 51                                           130        0.300406  4.774651
# 52                                           130        0.300406  4.491834
# ...                                          ...             ...       ...
# 39995                                 tree_mixed        0.259076  0.339181
# 39996                                 tree_mixed        0.199880  0.509923
# 39997                                 tree_mixed        0.199880  0.509923
# 39998  tree_broadleaved_deciduous_closed_to_open        0.199880  0.789099
# 39999                                 tree_mixed        0.199880  0.789099
#
# [34511 rows x 14 columns]

# %%
import matplotlib as plt
#fdf = pd.DataFrame(model.predict_proba())
print(model.predict_proba(pd.DataFrame([fail.iloc[21]])))
#fdf.plot()
# Out:
# [[0.92314393 0.07685607]]

# %%
fail
# Out:
#        latitude  longitude acq_date acq_time instrument  confidence  \
# 46        52.70       5.00                                      NaN
# 47        52.65       5.00                                      NaN
# 50        52.50       5.00                                      NaN
# 51        52.45       5.00                                      NaN
# 52        52.40       5.00                                      NaN
# ...         ...        ...      ...      ...        ...         ...
# 39995     45.25      14.95                                      NaN
# 39996     45.20      14.95                                      NaN
# 39997     45.15      14.95                                      NaN
# 39998     45.10      14.95                                      NaN
# 39999     45.05      14.95                                      NaN
#
#        x_confirmed  x_dewpoint frp     x_temp     x_pressure  \
# 46           False  283.199280      17.404443  102239.812500
# 47           False  283.199280      17.404443  102239.812500
# 50           False  283.314972      17.606165  102185.828125
# 51           False  283.314972      17.606165  102185.828125
# 52           False  283.365784      17.741998  102202.875000
# ...            ...         ...  ..        ...            ...
# 39995        False  284.669708      22.936975   91370.609375
# 39996        False  283.861755      23.074762   91182.132812
# 39997        False  283.861755      23.074762   91182.132812
# 39998        False  285.125366      25.098047   94091.695312
# 39999        False  285.125366      25.098047   94091.695312
#
#                                        x_landuse  x_soilmoisture    x_wind
# 46                                           130        0.332273  5.448339
# 47                                           130        0.332273  5.448339
# 50                     mosaic_natural_vegetation        0.332273  4.774651
# 51                                           130        0.300406  4.774651
# 52                                           130        0.300406  4.491834
# ...                                          ...             ...       ...
# 39995                                 tree_mixed        0.259076  0.339181
# 39996                                 tree_mixed        0.199880  0.509923
# 39997                                 tree_mixed        0.199880  0.509923
# 39998  tree_broadleaved_deciduous_closed_to_open        0.199880  0.789099
# 39999                                 tree_mixed        0.199880  0.789099
#
# [34511 rows x 14 columns]

# %%
fail = fail[fail.x_landuse != "220"]
preds = model.predict_proba(fail)

# %%
len(preds)
# Out:
# 34424

# %%
len(fail)
# Out:
# 34424

# %%
grid = fail.insert(3, "fire_risk_inv", preds[:, 1])

# %%
gdf = geopandas.GeoDataFrame(
    fail, geometry=geopandas.points_from_xy(fail.longitude, fail.latitude))

# %%
import geoplot
import geopandas
import matplotlib

world = geopandas.read_file(
    geopandas.datasets.get_path('naturalearth_lowres')
)
boroughs = geopandas.read_file(
    geoplot.datasets.get_path('nyc_boroughs')
)
collisions = geopandas.read_file(
    geoplot.datasets.get_path('nyc_injurious_collisions')
)

# %%
#ax = geoplot.kdeplot(
#    collisions, clip=boroughs.geometry,
#    shade=True, cmap='Reds',
#    projection=geoplot.crs.AlbersEqualArea())
#geoplot.polyplot(boroughs, ax=ax, zorder=1)

# %%
geoplot.pointplot(df, projection=gcrs.AlbersEqualArea(), hue='DIP', legend=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1409bc2ba3b1> in <module>()
# ----> 1 geoplot.pointplot(df, projection=gcrs.AlbersEqualArea(), hue='DIP', legend=True)
#
# NameError: name 'geoplot' is not defined

# %%
geoplot.pointplot(df, projection=gcrs.AlbersEqualArea(), hue='DIP', legend=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1409bc2ba3b1> in <module>()
# ----> 1 geoplot.pointplot(df, projection=gcrs.AlbersEqualArea(), hue='DIP', legend=True)
#
# NameError: name 'df' is not defined

# %%
import geoplot
import geopandas
import geoplot.crs as gcrs
# %matplotlib inline
world = geopandas.read_file(
    geopandas.datasets.get_path('naturalearth_lowres')
)

gdf = geopandas.GeoDataFrame(fail, geometry=geopandas.points_from_xy(fail.longitude, fail.latitude))

# %% [markdown]
# A plot for the confidence for a Germany-wide grid of environmental data looks interesting, especially when compared to the Fire Weather Index map from EFFIS. There are still lots of differences, but there is definitively some correlation in Central Germany and at the German/Czech border.
#
# Erronous model response can be observed at the alps (which might be related to lots fires from the training data set being in mountains).
#
# ![wildfire risk](effis.png)

# %%
germany = world.query('name == "Germany"')
#africa = world.query('continent == "Europe"')
#ax = geoplot.cartogram(
#    gdf, scale='pop_est', limits=(0.2, 1),
#    edgecolor='None', figsize=(7, 8)
#)
#ax = geoplot.kdeplot(
#    gdf, shade=True, cmap='Reds', projection=geoplot.crs.AlbersEqualArea(),
#    hue='x_temp', clip=africa)


#ax = geoplot.voronoi(
#    gdf, cmap='viridis',
#    projection=geoplot.crs.AlbersEqualArea(),
#    clip=africa, hue="x_temp", legend=True, edgecolor='white')

#ax = geoplot.cartogram(
#    gdf, cmap='viridis',
#    projection=geoplot.crs.AlbersEqualArea(),
#    clip=africa, scale="x_temp", hue="x_soilmoisture" legend=True, edgecolor='white')

ax = geoplot.pointplot(
    gdf, cmap='viridis',
    projection=geoplot.crs.AlbersEqualArea(),
    hue="fire_risk_inv", legend=True, edgecolor='white', figsize=(32,16))

geoplot.polyplot(germany, ax=ax, zorder=1)

# %% [markdown]
# # Plot of surface air (2m) temperatures

# %%
ax = geoplot.pointplot(
    gdf, cmap='viridis',
    projection=geoplot.crs.AlbersEqualArea(),
    hue="x_temp", legend=True, edgecolor='white')

geoplot.polyplot(africa, ax=ax, zorder=1)

# %%
f
# Out:
# [{'latitude': 55.0,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.95,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.9,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.85,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.8,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.75,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.7,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.65,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.6,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.55,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.5,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.45,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.4,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.35,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.3,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.25,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.2,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.15,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.1,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.05,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 54.0,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.95,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.9,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.85,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.8,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.75,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.7,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.65,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.6,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.55,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.5,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.45,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.4,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.35,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.3,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.25,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.2,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.15,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.1,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.05,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 53.0,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 52.95,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '210',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 52.9,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': nan,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 52.85,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.0774738788604736,
#   'x_wind_v': -5.486462116241455,
#   'x_temp': 17.154779052734398,
#   'x_pressure': 102233.1875,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': nan,
#   'x_dewpoint': 283.5059814453125,
#   'x_wind': 5.866614378864546},
#  {'latitude': 52.8,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.0774738788604736,
#   'x_wind_v': -5.486462116241455,
#   'x_temp': 17.154779052734398,
#   'x_pressure': 102233.1875,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': nan,
#   'x_dewpoint': 283.5059814453125,
#   'x_wind': 5.866614378864546},
#  {'latitude': 52.75,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.0774738788604736,
#   'x_wind_v': -5.486462116241455,
#   'x_temp': 17.154779052734398,
#   'x_pressure': 102233.1875,
#   'x_landuse': '130',
#   'x_soilmoisture': nan,
#   'x_dewpoint': 283.5059814453125,
#   'x_wind': 5.866614378864546},
#  {'latitude': 52.7,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.0645124912261963,
#   'x_wind_v': -5.042041778564453,
#   'x_temp': 17.404443359375023,
#   'x_pressure': 102239.8125,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.33227264881134033,
#   'x_dewpoint': 283.19927978515625,
#   'x_wind': 5.44833893248377},
#  {'latitude': 52.65,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.0645124912261963,
#   'x_wind_v': -5.042041778564453,
#   'x_temp': 17.404443359375023,
#   'x_pressure': 102239.8125,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.33227264881134033,
#   'x_dewpoint': 283.19927978515625,
#   'x_wind': 5.44833893248377},
#  {'latitude': 52.6,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.33227264881134033,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 52.55,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': nan,
#   'x_wind_v': nan,
#   'x_temp': nan,
#   'x_pressure': nan,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.33227264881134033,
#   'x_dewpoint': nan,
#   'x_wind': nan},
#  {'latitude': 52.5,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.1343061923980713,
#   'x_wind_v': -4.271069049835205,
#   'x_temp': 17.606164550781273,
#   'x_pressure': 102185.828125,
#   'x_landuse': 'mosaic_natural_vegetation',
#   'x_soilmoisture': 0.33227264881134033,
#   'x_dewpoint': 283.3149719238281,
#   'x_wind': 4.774651165411873},
#  {'latitude': 52.45,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.1343061923980713,
#   'x_wind_v': -4.271069049835205,
#   'x_temp': 17.606164550781273,
#   'x_pressure': 102185.828125,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.30040615797042847,
#   'x_dewpoint': 283.3149719238281,
#   'x_wind': 4.774651165411873},
#  {'latitude': 52.4,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.182164430618286,
#   'x_wind_v': -3.9261603355407715,
#   'x_temp': 17.741998291015648,
#   'x_pressure': 102202.875,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.30040615797042847,
#   'x_dewpoint': 283.36578369140625,
#   'x_wind': 4.491834434017938},
#  {'latitude': 52.35,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.241987943649292,
#   'x_wind_v': -3.7503244876861572,
#   'x_temp': 17.879815673828148,
#   'x_pressure': 102190.5625,
#   'x_landuse': '190',
#   'x_soilmoisture': 0.30040615797042847,
#   'x_dewpoint': 283.19927978515625,
#   'x_wind': 4.3693756650587074},
#  {'latitude': 52.3,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.241987943649292,
#   'x_wind_v': -3.7503244876861572,
#   'x_temp': 17.879815673828148,
#   'x_pressure': 102190.5625,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.30040615797042847,
#   'x_dewpoint': 283.19927978515625,
#   'x_wind': 4.3693756650587074},
#  {'latitude': 52.25,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.241987943649292,
#   'x_wind_v': -3.7503244876861572,
#   'x_temp': 17.879815673828148,
#   'x_pressure': 102190.5625,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.30040615797042847,
#   'x_dewpoint': 283.19927978515625,
#   'x_wind': 4.3693756650587074},
#  {'latitude': 52.2,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.304802179336548,
#   'x_wind_v': -3.5841498374938965,
#   'x_temp': 18.057580566406273,
#   'x_pressure': 102183.9375,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.3300163149833679,
#   'x_dewpoint': 283.0380554199219,
#   'x_wind': 4.2612490121421},
#  {'latitude': 52.15,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.304802179336548,
#   'x_wind_v': -3.5841498374938965,
#   'x_temp': 18.057580566406273,
#   'x_pressure': 102183.9375,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.3300163149833679,
#   'x_dewpoint': 283.0380554199219,
#   'x_wind': 4.2612490121421},
#  {'latitude': 52.1,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.366619348526001,
#   'x_wind_v': -3.4517898559570312,
#   'x_temp': 18.151452636718773,
#   'x_pressure': 102191.515625,
#   'x_landuse': '190',
#   'x_soilmoisture': 0.3300163149833679,
#   'x_dewpoint': 282.91888427734375,
#   'x_wind': 4.1851810415447375},
#  {'latitude': 52.05,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.366619348526001,
#   'x_wind_v': -3.4517898559570312,
#   'x_temp': 18.151452636718773,
#   'x_pressure': 102191.515625,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.3300163149833679,
#   'x_dewpoint': 282.91888427734375,
#   'x_wind': 4.1851810415447375},
#  {'latitude': 52.0,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.4124839305877686,
#   'x_wind_v': -3.4005849361419678,
#   'x_temp': 18.271264648437523,
#   'x_pressure': 102192.4609375,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.3300163149833679,
#   'x_dewpoint': 282.745361328125,
#   'x_wind': 4.169419218939237},
#  {'latitude': 51.95,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.4124839305877686,
#   'x_wind_v': -3.4005849361419678,
#   'x_temp': 18.271264648437523,
#   'x_pressure': 102192.4609375,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.3676500916481018,
#   'x_dewpoint': 282.745361328125,
#   'x_wind': 4.169419218939237},
#  {'latitude': 51.9,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.4603421688079834,
#   'x_wind_v': -3.3426170349121094,
#   'x_temp': 18.417077636718773,
#   'x_pressure': 102199.0859375,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.3676500916481018,
#   'x_dewpoint': 282.5420837402344,
#   'x_wind': 4.150466507478333},
#  {'latitude': 51.85,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.4304306507110596,
#   'x_wind_v': -3.2460038661956787,
#   'x_temp': 18.590844726562523,
#   'x_pressure': 102182.0390625,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.3676500916481018,
#   'x_dewpoint': 282.48248291015625,
#   'x_wind': 4.0550627920259235},
#  {'latitude': 51.8,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.4304306507110596,
#   'x_wind_v': -3.2460038661956787,
#   'x_temp': 18.590844726562523,
#   'x_pressure': 102182.0390625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.3676500916481018,
#   'x_dewpoint': 282.48248291015625,
#   'x_wind': 4.0550627920259235},
#  {'latitude': 51.75,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.4304306507110596,
#   'x_wind_v': -3.2460038661956787,
#   'x_temp': 18.590844726562523,
#   'x_pressure': 102182.0390625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.3676500916481018,
#   'x_dewpoint': 282.48248291015625,
#   'x_wind': 4.0550627920259235},
#  {'latitude': 51.7,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.3396990299224854,
#   'x_wind_v': -3.112677812576294,
#   'x_temp': 18.766595458984398,
#   'x_pressure': 102119.53125,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.2680145502090454,
#   'x_dewpoint': 282.5245361328125,
#   'x_wind': 3.8939638821546563},
#  {'latitude': 51.65,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.3396990299224854,
#   'x_wind_v': -3.112677812576294,
#   'x_temp': 18.766595458984398,
#   'x_pressure': 102119.53125,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2680145502090454,
#   'x_dewpoint': 282.5245361328125,
#   'x_wind': 3.8939638821546563},
#  {'latitude': 51.6,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.2459757328033447,
#   'x_wind_v': -2.9803178310394287,
#   'x_temp': 18.936364746093773,
#   'x_pressure': 102074.0703125,
#   'x_landuse': '190',
#   'x_soilmoisture': 0.2680145502090454,
#   'x_dewpoint': 282.52630615234375,
#   'x_wind': 3.7318495905318967},
#  {'latitude': 51.55,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.2459757328033447,
#   'x_wind_v': -2.9803178310394287,
#   'x_temp': 18.936364746093773,
#   'x_pressure': 102074.0703125,
#   'x_landuse': 'tree_needleleaved_evergreen_closed_to_open',
#   'x_soilmoisture': 0.2680145502090454,
#   'x_dewpoint': 282.52630615234375,
#   'x_wind': 3.7318495905318967},
#  {'latitude': 51.5,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.182164430618286,
#   'x_wind_v': -2.8653483390808105,
#   'x_temp': 19.058221435546898,
#   'x_pressure': 102013.453125,
#   'x_landuse': 'tree_needleleaved_evergreen_closed_to_open',
#   'x_soilmoisture': 0.2680145502090454,
#   'x_dewpoint': 282.40185546875,
#   'x_wind': 3.601674986243038},
#  {'latitude': 51.45,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.182164430618286,
#   'x_wind_v': -2.8653483390808105,
#   'x_temp': 19.058221435546898,
#   'x_pressure': 102013.453125,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2727159261703491,
#   'x_dewpoint': 282.40185546875,
#   'x_wind': 3.601674986243038},
#  {'latitude': 51.4,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.128323793411255,
#   'x_wind_v': -2.7494125366210938,
#   'x_temp': 19.120141601562523,
#   'x_pressure': 101925.3671875,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.2727159261703491,
#   'x_dewpoint': 282.1477355957031,
#   'x_wind': 3.476928452834443},
#  {'latitude': 51.35,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.0744826793670654,
#   'x_wind_v': -2.635409116744995,
#   'x_temp': 19.263940429687523,
#   'x_pressure': 101895.0625,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.2727159261703491,
#   'x_dewpoint': 281.9216613769531,
#   'x_wind': 3.353931961089341},
#  {'latitude': 51.3,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.0744826793670654,
#   'x_wind_v': -2.635409116744995,
#   'x_temp': 19.263940429687523,
#   'x_pressure': 101895.0625,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.2727159261703491,
#   'x_dewpoint': 281.9216613769531,
#   'x_wind': 3.353931961089341},
#  {'latitude': 51.25,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.0744826793670654,
#   'x_wind_v': -2.635409116744995,
#   'x_temp': 19.263940429687523,
#   'x_pressure': 101895.0625,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.2727159261703491,
#   'x_dewpoint': 281.9216613769531,
#   'x_wind': 3.353931961089341},
#  {'latitude': 51.2,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.039585828781128,
#   'x_wind_v': -2.6257476806640625,
#   'x_temp': 19.475640869140648,
#   'x_pressure': 101941.46875,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.2959209680557251,
#   'x_dewpoint': 281.89361572265625,
#   'x_wind': 3.3248249932105454},
#  {'latitude': 51.15,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.039585828781128,
#   'x_wind_v': -2.6257476806640625,
#   'x_temp': 19.475640869140648,
#   'x_pressure': 101941.46875,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2959209680557251,
#   'x_dewpoint': 281.89361572265625,
#   'x_wind': 3.3248249932105454},
#  {'latitude': 51.1,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.010671377182007,
#   'x_wind_v': -2.6412057876586914,
#   'x_temp': 19.455682373046898,
#   'x_pressure': 101882.75,
#   'x_landuse': '190',
#   'x_soilmoisture': 0.2959209680557251,
#   'x_dewpoint': 281.8480529785156,
#   'x_wind': 3.319452876571794},
#  {'latitude': 51.05,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 2.010671377182007,
#   'x_wind_v': -2.6412057876586914,
#   'x_temp': 19.455682373046898,
#   'x_pressure': 101882.75,
#   'x_landuse': '190',
#   'x_soilmoisture': 0.2959209680557251,
#   'x_dewpoint': 281.8480529785156,
#   'x_wind': 3.319452876571794},
#  {'latitude': 51.0,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.9797627925872803,
#   'x_wind_v': -2.675020456314087,
#   'x_temp': 19.513604736328148,
#   'x_pressure': 101804.140625,
#   'x_landuse': 'cropland_rainfed',
#   'x_soilmoisture': 0.2959209680557251,
#   'x_dewpoint': 281.7867126464844,
#   'x_wind': 3.32794157950704},
#  {'latitude': 50.95,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.9797627925872803,
#   'x_wind_v': -2.675020456314087,
#   'x_temp': 19.513604736328148,
#   'x_pressure': 101804.140625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2950766682624817,
#   'x_dewpoint': 281.7867126464844,
#   'x_wind': 3.32794157950704},
#  {'latitude': 50.9,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.9089720249176025,
#   'x_wind_v': -2.83829665184021,
#   'x_temp': 19.369775390625023,
#   'x_pressure': 101602.3984375,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2950766682624817,
#   'x_dewpoint': 281.85858154296875,
#   'x_wind': 3.4205411963263},
#  {'latitude': 50.85,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.8361871242523193,
#   'x_wind_v': -2.9986743927001953,
#   'x_temp': 19.337823486328148,
#   'x_pressure': 101330.578125,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2950766682624817,
#   'x_dewpoint': 281.79547119140625,
#   'x_wind': 3.5161955674714522},
#  {'latitude': 50.8,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.8361871242523193,
#   'x_wind_v': -2.9986743927001953,
#   'x_temp': 19.337823486328148,
#   'x_pressure': 101330.578125,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2950766682624817,
#   'x_dewpoint': 281.79547119140625,
#   'x_wind': 3.5161955674714522},
#  {'latitude': 50.75,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.8361871242523193,
#   'x_wind_v': -2.9986743927001953,
#   'x_temp': 19.337823486328148,
#   'x_pressure': 101330.578125,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2950766682624817,
#   'x_dewpoint': 281.79547119140625,
#   'x_wind': 3.5161955674714522},
#  {'latitude': 50.7,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.7314965724945068,
#   'x_wind_v': -3.1435940265655518,
#   'x_temp': 19.176049804687523,
#   'x_pressure': 100897.7421875,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.24327309429645538,
#   'x_dewpoint': 281.61846923828125,
#   'x_wind': 3.5889084391244706},
#  {'latitude': 50.65,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.7314965724945068,
#   'x_wind_v': -3.1435940265655518,
#   'x_temp': 19.176049804687523,
#   'x_pressure': 100897.7421875,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.24327309429645538,
#   'x_dewpoint': 281.61846923828125,
#   'x_wind': 3.5889084391244706},
#  {'latitude': 50.6,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.5540211200714111,
#   'x_wind_v': -3.2199184894561768,
#   'x_temp': 19.114129638671898,
#   'x_pressure': 100581.3984375,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.24327309429645538,
#   'x_dewpoint': 281.5343322753906,
#   'x_wind': 3.5753121150984497},
#  {'latitude': 50.55,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.5540211200714111,
#   'x_wind_v': -3.2199184894561768,
#   'x_temp': 19.114129638671898,
#   'x_pressure': 100581.3984375,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.24327309429645538,
#   'x_dewpoint': 281.5343322753906,
#   'x_wind': 3.5753121150984497},
#  {'latitude': 50.5,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.3745520114898682,
#   'x_wind_v': -3.2991411685943604,
#   'x_temp': 19.022271728515648,
#   'x_pressure': 100151.40625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.24327309429645538,
#   'x_dewpoint': 281.3380432128906,
#   'x_wind': 3.5740349302441077},
#  {'latitude': 50.45,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.3745520114898682,
#   'x_wind_v': -3.2991411685943604,
#   'x_temp': 19.022271728515648,
#   'x_pressure': 100151.40625,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.34665465354919434,
#   'x_dewpoint': 281.3380432128906,
#   'x_wind': 3.5740349302441077},
#  {'latitude': 50.4,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 1.1681618690490723,
#   'x_wind_v': -3.3658041954040527,
#   'x_temp': 18.732659912109398,
#   'x_pressure': 99375.7109375,
#   'x_landuse': 'mosaic_tree_and_shrub',
#   'x_soilmoisture': 0.34665465354919434,
#   'x_dewpoint': 281.02960205078125,
#   'x_wind': 3.5627573639106753},
#  {'latitude': 50.35,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.9248809814453125,
#   'x_wind_v': -3.4054155349731445,
#   'x_temp': 18.556878662109398,
#   'x_pressure': 99069.7890625,
#   'x_landuse': 'mosaic_tree_and_shrub',
#   'x_soilmoisture': 0.34665465354919434,
#   'x_dewpoint': 281.0313415527344,
#   'x_wind': 3.5287759628057533},
#  {'latitude': 50.3,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.9248809814453125,
#   'x_wind_v': -3.4054155349731445,
#   'x_temp': 18.556878662109398,
#   'x_pressure': 99069.7890625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.34665465354919434,
#   'x_dewpoint': 281.0313415527344,
#   'x_wind': 3.5287759628057533},
#  {'latitude': 50.25,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.9248809814453125,
#   'x_wind_v': -3.4054155349731445,
#   'x_temp': 18.556878662109398,
#   'x_pressure': 99069.7890625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.34665465354919434,
#   'x_dewpoint': 281.0313415527344,
#   'x_wind': 3.5287759628057533},
#  {'latitude': 50.2,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.6816000938415527,
#   'x_wind_v': -3.449857711791992,
#   'x_temp': 18.882440185546898,
#   'x_pressure': 99595.4453125,
#   'x_landuse': 'mosaic_tree_and_shrub',
#   'x_soilmoisture': 0.290181964635849,
#   'x_dewpoint': 281.4151611328125,
#   'x_wind': 3.5165461634301765},
#  {'latitude': 50.15,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.6816000938415527,
#   'x_wind_v': -3.449857711791992,
#   'x_temp': 18.882440185546898,
#   'x_pressure': 99595.4453125,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.290181964635849,
#   'x_dewpoint': 281.4151611328125,
#   'x_wind': 3.5165461634301765},
#  {'latitude': 50.1,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.4821896553039551,
#   'x_wind_v': -3.4836721420288086,
#   'x_temp': 18.824517822265648,
#   'x_pressure': 99368.1328125,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.290181964635849,
#   'x_dewpoint': 281.6149597167969,
#   'x_wind': 3.5168847659298894},
#  {'latitude': 50.05,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.4821896553039551,
#   'x_wind_v': -3.4836721420288086,
#   'x_temp': 18.824517822265648,
#   'x_pressure': 99368.1328125,
#   'x_landuse': 'tree_mixed',
#   'x_soilmoisture': 0.290181964635849,
#   'x_dewpoint': 281.6149597167969,
#   'x_wind': 3.5168847659298894},
#  {'latitude': 50.0,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.3106966018676758,
#   'x_wind_v': -3.5126562118530273,
#   'x_temp': 18.337182617187523,
#   'x_pressure': 98197.484375,
#   'x_landuse': 'tree_mixed',
#   'x_soilmoisture': 0.290181964635849,
#   'x_dewpoint': 281.4607238769531,
#   'x_wind': 3.5263700941735796},
#  {'latitude': 49.95,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.3106966018676758,
#   'x_wind_v': -3.5126562118530273,
#   'x_temp': 18.337182617187523,
#   'x_pressure': 98197.484375,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.24476973712444305,
#   'x_dewpoint': 281.4607238769531,
#   'x_wind': 3.5263700941735796},
#  {'latitude': 49.9,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.13920331001281738,
#   'x_wind_v': -3.5300464630126953,
#   'x_temp': 18.189385986328148,
#   'x_pressure': 97731.5,
#   'x_landuse': 'mosaic_tree_and_shrub',
#   'x_soilmoisture': 0.24476973712444305,
#   'x_dewpoint': 281.64825439453125,
#   'x_wind': 3.5327900578079876},
#  {'latitude': 49.85,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.09732723981142044,
#   'x_wind_v': -3.3754656314849854,
#   'x_temp': 18.948358154296898,
#   'x_pressure': 98704.1953125,
#   'x_landuse': 'tree_mixed',
#   'x_soilmoisture': 0.24476973712444305,
#   'x_dewpoint': 282.4439392089844,
#   'x_wind': 3.376868493285701},
#  {'latitude': 49.8,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.09732723981142044,
#   'x_wind_v': -3.3754656314849854,
#   'x_temp': 18.948358154296898,
#   'x_pressure': 98704.1953125,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.24476973712444305,
#   'x_dewpoint': 282.4439392089844,
#   'x_wind': 3.376868493285701},
#  {'latitude': 49.75,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.09732723981142044,
#   'x_wind_v': -3.3754656314849854,
#   'x_temp': 18.948358154296898,
#   'x_pressure': 98704.1953125,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.24476973712444305,
#   'x_dewpoint': 282.4439392089844,
#   'x_wind': 3.376868493285701},
#  {'latitude': 49.7,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.10330963879823685,
#   'x_wind_v': -3.180306911468506,
#   'x_temp': 19.705346679687523,
#   'x_pressure': 99444.8515625,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.2918742597103119,
#   'x_dewpoint': 283.03631591796875,
#   'x_wind': 3.181984433117637},
#  {'latitude': 49.65,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.10330963879823685,
#   'x_wind_v': -3.180306911468506,
#   'x_temp': 19.705346679687523,
#   'x_pressure': 99444.8515625,
#   'x_landuse': 'mosaic_herbaceous',
#   'x_soilmoisture': 0.2918742597103119,
#   'x_dewpoint': 283.03631591796875,
#   'x_wind': 3.181984433117637},
#  {'latitude': 49.6,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.10829473286867142,
#   'x_wind_v': -2.997708320617676,
#   'x_temp': 20.064843750000023,
#   'x_pressure': 99573.65625,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.2918742597103119,
#   'x_dewpoint': 283.31671142578125,
#   'x_wind': 2.9996638019397346},
#  {'latitude': 49.55,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.10829473286867142,
#   'x_wind_v': -2.997708320617676,
#   'x_temp': 20.064843750000023,
#   'x_pressure': 99573.65625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2918742597103119,
#   'x_dewpoint': 283.31671142578125,
#   'x_wind': 2.9996638019397346},
#  {'latitude': 49.5,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.08037734776735306,
#   'x_wind_v': -2.9523000717163086,
#   'x_temp': 20.100793457031273,
#   'x_pressure': 99348.2421875,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.2918742597103119,
#   'x_dewpoint': 283.2027893066406,
#   'x_wind': 2.9533940190042767},
#  {'latitude': 49.45,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.08037734776735306,
#   'x_wind_v': -2.9523000717163086,
#   'x_temp': 20.100793457031273,
#   'x_pressure': 99348.2421875,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.35087624192237854,
#   'x_dewpoint': 283.2027893066406,
#   'x_wind': 2.9533940190042767},
#  {'latitude': 49.4,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.05046582967042923,
#   'x_wind_v': -2.9155871868133545,
#   'x_temp': 20.250604248046898,
#   'x_pressure': 99416.4375,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.35087624192237854,
#   'x_dewpoint': 283.2694091796875,
#   'x_wind': 2.916023910031352},
#  {'latitude': 49.35,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.03650689870119095,
#   'x_wind_v': -2.857619285583496,
#   'x_temp': 20.538201904296898,
#   'x_pressure': 99733.71875,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.35087624192237854,
#   'x_dewpoint': 283.4726867675781,
#   'x_wind': 2.8578524690738516},
#  {'latitude': 49.3,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.03650689870119095,
#   'x_wind_v': -2.857619285583496,
#   'x_temp': 20.538201904296898,
#   'x_pressure': 99733.71875,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.35087624192237854,
#   'x_dewpoint': 283.4726867675781,
#   'x_wind': 2.8578524690738516},
#  {'latitude': 49.25,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.03650689870119095,
#   'x_wind_v': -2.857619285583496,
#   'x_temp': 20.538201904296898,
#   'x_pressure': 99733.71875,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.35087624192237854,
#   'x_dewpoint': 283.4726867675781,
#   'x_wind': 2.8578524690738516},
#  {'latitude': 49.2,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.0933389738202095,
#   'x_wind_v': -2.7329883575439453,
#   'x_temp': 20.598138427734398,
#   'x_pressure': 99852.109375,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.30128219723701477,
#   'x_dewpoint': 283.6427001953125,
#   'x_wind': 2.7345817827420267},
#  {'latitude': 49.15,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.0933389738202095,
#   'x_wind_v': -2.7329883575439453,
#   'x_temp': 20.598138427734398,
#   'x_pressure': 99852.109375,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.30128219723701477,
#   'x_dewpoint': 283.6427001953125,
#   'x_wind': 2.7345817827420267},
#  {'latitude': 49.1,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.15017104148864746,
#   'x_wind_v': -2.614154100418091,
#   'x_temp': 20.540216064453148,
#   'x_pressure': 99796.234375,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.30128219723701477,
#   'x_dewpoint': 283.7005310058594,
#   'x_wind': 2.6184638631141164},
#  {'latitude': 49.05,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.15017104148864746,
#   'x_wind_v': -2.614154100418091,
#   'x_temp': 20.540216064453148,
#   'x_pressure': 99796.234375,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.30128219723701477,
#   'x_dewpoint': 283.7005310058594,
#   'x_wind': 2.6184638631141164},
#  {'latitude': 49.0,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.23492050170898438,
#   'x_wind_v': -2.4972522258758545,
#   'x_temp': 20.492272949218773,
#   'x_pressure': 99864.421875,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.30128219723701477,
#   'x_dewpoint': 283.8845520019531,
#   'x_wind': 2.508277560750626},
#  {'latitude': 48.95,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.23492050170898438,
#   'x_wind_v': -2.4972522258758545,
#   'x_temp': 20.492272949218773,
#   'x_pressure': 99864.421875,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.28576454520225525,
#   'x_dewpoint': 283.8845520019531,
#   'x_wind': 2.508277560750626},
#  {'latitude': 48.9,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.3545668125152588,
#   'x_wind_v': -2.3774521350860596,
#   'x_temp': 20.480279541015648,
#   'x_pressure': 100025.4375,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.28576454520225525,
#   'x_dewpoint': 284.1351623535156,
#   'x_wind': 2.4037463009149893},
#  {'latitude': 48.85,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.4742131233215332,
#   'x_wind_v': -2.2595839500427246,
#   'x_temp': 20.404382324218773,
#   'x_pressure': 99963.875,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.28576454520225525,
#   'x_dewpoint': 284.19476318359375,
#   'x_wind': 2.308808721748306},
#  {'latitude': 48.8,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.4742131233215332,
#   'x_wind_v': -2.2595839500427246,
#   'x_temp': 20.404382324218773,
#   'x_pressure': 99963.875,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.28576454520225525,
#   'x_dewpoint': 284.19476318359375,
#   'x_wind': 2.308808721748306},
#  {'latitude': 48.75,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.4742131233215332,
#   'x_wind_v': -2.2595839500427246,
#   'x_temp': 20.404382324218773,
#   'x_pressure': 99963.875,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.28576454520225525,
#   'x_dewpoint': 284.19476318359375,
#   'x_wind': 2.308808721748306},
#  {'latitude': 48.7,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.5719244480133057,
#   'x_wind_v': -2.19581937789917,
#   'x_temp': 20.324487304687523,
#   'x_pressure': 99846.4296875,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.3241356909275055,
#   'x_dewpoint': 284.2315673828125,
#   'x_wind': 2.269079177682617},
#  {'latitude': 48.65,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.5719244480133057,
#   'x_wind_v': -2.19581937789917,
#   'x_temp': 20.324487304687523,
#   'x_pressure': 99846.4296875,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.3241356909275055,
#   'x_dewpoint': 284.2315673828125,
#   'x_wind': 2.269079177682617},
#  {'latitude': 48.6,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.6536827087402344,
#   'x_wind_v': -2.1793951988220215,
#   'x_temp': 20.236627197265648,
#   'x_pressure': 99800.0234375,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.3241356909275055,
#   'x_dewpoint': 284.4068298339844,
#   'x_wind': 2.2753163552250153},
#  {'latitude': 48.55,
#   'longitude': 5.0,
#   'acq_date': '',
#   'acq_time': '',
# ...
#   'x_wind_v': -1.7117875814437866,
#   'x_temp': 22.016198730468773,
#   'x_pressure': 99881.4765625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.21313966810703278,
#   'x_dewpoint': 281.93218994140625,
#   'x_wind': 1.7910232459929585},
#  {'latitude': 46.9,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.314455509185791,
#   'x_wind_v': -1.6924649477005005,
#   'x_temp': 21.860406494140648,
#   'x_pressure': 99549.03125,
#   'x_landuse': 'cropland_rainfed',
#   'x_soilmoisture': 0.21313966810703278,
#   'x_dewpoint': 281.5956726074219,
#   'x_wind': 1.721429599621243},
#  {'latitude': 46.85,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.10407733172178268,
#   'x_wind_v': -1.6828036308288574,
#   'x_temp': 21.910363769531273,
#   'x_pressure': 99475.15625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.21313966810703278,
#   'x_dewpoint': 281.3012390136719,
#   'x_wind': 1.686019024480184},
#  {'latitude': 46.8,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.10407733172178268,
#   'x_wind_v': -1.6828036308288574,
#   'x_temp': 21.910363769531273,
#   'x_pressure': 99475.15625,
#   'x_landuse': 'cropland_rainfed',
#   'x_soilmoisture': 0.21313966810703278,
#   'x_dewpoint': 281.3012390136719,
#   'x_wind': 1.686019024480184},
#  {'latitude': 46.75,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.10407733172178268,
#   'x_wind_v': -1.6828036308288574,
#   'x_temp': 21.910363769531273,
#   'x_pressure': 99475.15625,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.21313966810703278,
#   'x_dewpoint': 281.3012390136719,
#   'x_wind': 1.686019024480184},
#  {'latitude': 46.7,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.10929179936647415,
#   'x_wind_v': -1.7919764518737793,
#   'x_temp': 22.032189941406273,
#   'x_pressure': 99752.6640625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2347283810377121,
#   'x_dewpoint': 281.3222961425781,
#   'x_wind': 1.795306185996946},
#  {'latitude': 46.65,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.10929179936647415,
#   'x_wind_v': -1.7919764518737793,
#   'x_temp': 22.032189941406273,
#   'x_pressure': 99752.6640625,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.2347283810377121,
#   'x_dewpoint': 281.3222961425781,
#   'x_wind': 1.795306185996946},
#  {'latitude': 46.6,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.3376169204711914,
#   'x_wind_v': -1.9282009601593018,
#   'x_temp': 21.990228271484398,
#   'x_pressure': 99800.0234375,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.2347283810377121,
#   'x_dewpoint': 281.1908264160156,
#   'x_wind': 1.9575352174987055},
#  {'latitude': 46.55,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.3376169204711914,
#   'x_wind_v': -1.9282009601593018,
#   'x_temp': 21.990228271484398,
#   'x_pressure': 99800.0234375,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.2347283810377121,
#   'x_dewpoint': 281.1908264160156,
#   'x_wind': 1.9575352174987055},
#  {'latitude': 46.5,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.5549743175506592,
#   'x_wind_v': -2.062493324279785,
#   'x_temp': 21.610742187500023,
#   'x_pressure': 99405.0703125,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.2347283810377121,
#   'x_dewpoint': 280.8911437988281,
#   'x_wind': 2.1358546780714036},
#  {'latitude': 46.45,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.5549743175506592,
#   'x_wind_v': -2.062493324279785,
#   'x_temp': 21.610742187500023,
#   'x_pressure': 99405.0703125,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.24753592908382416,
#   'x_dewpoint': 280.8911437988281,
#   'x_wind': 2.1358546780714036},
#  {'latitude': 46.4,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.6157946586608887,
#   'x_wind_v': -2.189056396484375,
#   'x_temp': 21.223291015625023,
#   'x_pressure': 99024.328125,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.24753592908382416,
#   'x_dewpoint': 280.948974609375,
#   'x_wind': 2.2740208813079175},
#  {'latitude': 46.35,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.6726267337799072,
#   'x_wind_v': -2.317551851272583,
#   'x_temp': 20.969628906250023,
#   'x_pressure': 98862.3671875,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.24753592908382416,
#   'x_dewpoint': 281.12249755859375,
#   'x_wind': 2.413187374890811},
#  {'latitude': 46.3,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.6726267337799072,
#   'x_wind_v': -2.317551851272583,
#   'x_temp': 20.969628906250023,
#   'x_pressure': 98862.3671875,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.24753592908382416,
#   'x_dewpoint': 281.12249755859375,
#   'x_wind': 2.413187374890811},
#  {'latitude': 46.25,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.6726267337799072,
#   'x_wind_v': -2.317551851272583,
#   'x_temp': 20.969628906250023,
#   'x_pressure': 98862.3671875,
#   'x_landuse': '130',
#   'x_soilmoisture': 0.24753592908382416,
#   'x_dewpoint': 281.12249755859375,
#   'x_wind': 2.413187374890811},
#  {'latitude': 46.2,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.717494010925293,
#   'x_wind_v': -2.4518442153930664,
#   'x_temp': 20.777886962890648,
#   'x_pressure': 98690.9375,
#   'x_landuse': '190',
#   'x_soilmoisture': 0.2678307592868805,
#   'x_dewpoint': 281.2153625488281,
#   'x_wind': 2.5546697853675933},
#  {'latitude': 46.15,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.717494010925293,
#   'x_wind_v': -2.4518442153930664,
#   'x_temp': 20.777886962890648,
#   'x_pressure': 98690.9375,
#   'x_landuse': 'cropland_rainfed',
#   'x_soilmoisture': 0.2678307592868805,
#   'x_dewpoint': 281.2153625488281,
#   'x_wind': 2.5546697853675933},
#  {'latitude': 46.1,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.7314527034759521,
#   'x_wind_v': -2.607391119003296,
#   'x_temp': 20.785882568359398,
#   'x_pressure': 98685.2578125,
#   'x_landuse': 'cropland_rainfed',
#   'x_soilmoisture': 0.2678307592868805,
#   'x_dewpoint': 281.44146728515625,
#   'x_wind': 2.7080456984474135},
#  {'latitude': 46.05,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.7314527034759521,
#   'x_wind_v': -2.607391119003296,
#   'x_temp': 20.785882568359398,
#   'x_pressure': 98685.2578125,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2678307592868805,
#   'x_dewpoint': 281.44146728515625,
#   'x_wind': 2.7080456984474135},
#  {'latitude': 46.0,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.7493996620178223,
#   'x_wind_v': -2.761972188949585,
#   'x_temp': 20.833795166015648,
#   'x_pressure': 98619.90625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2678307592868805,
#   'x_dewpoint': 281.42041015625,
#   'x_wind': 2.861833367958971},
#  {'latitude': 45.95,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.7493996620178223,
#   'x_wind_v': -2.761972188949585,
#   'x_temp': 20.833795166015648,
#   'x_pressure': 98619.90625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.26813942193984985,
#   'x_dewpoint': 281.42041015625,
#   'x_wind': 2.861833367958971},
#  {'latitude': 45.9,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.7513937950134277,
#   'x_wind_v': -2.833465814590454,
#   'x_temp': 20.953637695312523,
#   'x_pressure': 98626.53125,
#   'x_landuse': '190',
#   'x_soilmoisture': 0.26813942193984985,
#   'x_dewpoint': 281.3135070800781,
#   'x_wind': 2.931402592213739},
#  {'latitude': 45.85,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.7264676094055176,
#   'x_wind_v': -2.8199400901794434,
#   'x_temp': 21.323144531250023,
#   'x_pressure': 99192.9140625,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.26813942193984985,
#   'x_dewpoint': 281.6815490722656,
#   'x_wind': 2.912012585775792},
#  {'latitude': 45.8,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.7264676094055176,
#   'x_wind_v': -2.8199400901794434,
#   'x_temp': 21.323144531250023,
#   'x_pressure': 99192.9140625,
#   'x_landuse': 'cropland_rainfed',
#   'x_soilmoisture': 0.26813942193984985,
#   'x_dewpoint': 281.6815490722656,
#   'x_wind': 2.912012585775792},
#  {'latitude': 45.75,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.7264676094055176,
#   'x_wind_v': -2.8199400901794434,
#   'x_temp': 21.323144531250023,
#   'x_pressure': 99192.9140625,
#   'x_landuse': '190',
#   'x_soilmoisture': 0.26813942193984985,
#   'x_dewpoint': 281.6815490722656,
#   'x_wind': 2.912012585775792},
#  {'latitude': 45.7,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.6905736923217773,
#   'x_wind_v': -2.805448055267334,
#   'x_temp': 21.129418945312523,
#   'x_pressure': 98862.3671875,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2870599031448364,
#   'x_dewpoint': 281.5483703613281,
#   'x_wind': 2.8891920696503024},
#  {'latitude': 45.65,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.6905736923217773,
#   'x_wind_v': -2.805448055267334,
#   'x_temp': 21.129418945312523,
#   'x_pressure': 98862.3671875,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2870599031448364,
#   'x_dewpoint': 281.5483703613281,
#   'x_wind': 2.8891920696503024},
#  {'latitude': 45.6,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.4632456302642822,
#   'x_wind_v': -2.9001290798187256,
#   'x_temp': 19.992944335937523,
#   'x_pressure': 97118.7109375,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.2870599031448364,
#   'x_dewpoint': 280.9665222167969,
#   'x_wind': 2.936893800185693},
#  {'latitude': 45.55,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.4632456302642822,
#   'x_wind_v': -2.9001290798187256,
#   'x_temp': 19.992944335937523,
#   'x_pressure': 97118.7109375,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.2870599031448364,
#   'x_dewpoint': 280.9665222167969,
#   'x_wind': 2.936893800185693},
#  {'latitude': 45.5,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.13621234893798828,
#   'x_wind_v': -3.0527777671813965,
#   'x_temp': 19.367791748046898,
#   'x_pressure': 96158.328125,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.2870599031448364,
#   'x_dewpoint': 280.9524841308594,
#   'x_wind': 3.0558150958132653},
#  {'latitude': 45.45,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': 0.13621234893798828,
#   'x_wind_v': -3.0527777671813965,
#   'x_temp': 19.367791748046898,
#   'x_pressure': 96158.328125,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.2607005536556244,
#   'x_dewpoint': 280.9524841308594,
#   'x_wind': 3.0558150958132653},
#  {'latitude': 45.4,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.18683290481567383,
#   'x_wind_v': -3.2025279998779297,
#   'x_temp': 19.447686767578148,
#   'x_pressure': 96292.8203125,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.2607005536556244,
#   'x_dewpoint': 281.3818664550781,
#   'x_wind': 3.207973211285281},
#  {'latitude': 45.35,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.38823747634887695,
#   'x_wind_v': -3.3223283290863037,
#   'x_temp': 19.409722900390648,
#   'x_pressure': 96288.078125,
#   'x_landuse': 'cropland_rainfed',
#   'x_soilmoisture': 0.2607005536556244,
#   'x_dewpoint': 281.88836669921875,
#   'x_wind': 3.3449355545796595},
#  {'latitude': 45.3,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.38823747634887695,
#   'x_wind_v': -3.3223283290863037,
#   'x_temp': 19.409722900390648,
#   'x_pressure': 96288.078125,
#   'x_landuse': 'mosaic_cropland',
#   'x_soilmoisture': 0.2607005536556244,
#   'x_dewpoint': 281.88836669921875,
#   'x_wind': 3.3449355545796595},
#  {'latitude': 45.25,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.38823747634887695,
#   'x_wind_v': -3.3223283290863037,
#   'x_temp': 19.409722900390648,
#   'x_pressure': 96288.078125,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.2607005536556244,
#   'x_dewpoint': 281.88836669921875,
#   'x_wind': 3.3449355545796595},
#  {'latitude': 45.2,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.5547451972961426,
#   'x_wind_v': -3.426670551300049,
#   'x_temp': 19.779229736328148,
#   'x_pressure': 97248.46875,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.256915807723999,
#   'x_dewpoint': 282.8277587890625,
#   'x_wind': 3.4712840997345804},
#  {'latitude': 45.15,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.5547451972961426,
#   'x_wind_v': -3.426670551300049,
#   'x_temp': 19.779229736328148,
#   'x_pressure': 97248.46875,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.256915807723999,
#   'x_dewpoint': 282.8277587890625,
#   'x_wind': 3.4712840997345804},
#  {'latitude': 45.1,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.700314998626709,
#   'x_wind_v': -3.5377755165100098,
#   'x_temp': 20.278558349609398,
#   'x_pressure': 98341.4453125,
#   'x_landuse': 'tree_broadleaved_deciduous_closed_to_open',
#   'x_soilmoisture': 0.256915807723999,
#   'x_dewpoint': 283.6637268066406,
#   'x_wind': 3.606424365284706},
#  {'latitude': 45.05,
#   'longitude': 5.2,
#   'acq_date': '',
#   'acq_time': '',
#   'instrument': '',
#   'x_confirmed': False,
#   'frp': '',
#   'x_wind_u': -0.700314998626709,
#   'x_wind_v': -3.5377755165100098,
#   'x_temp': 20.278558349609398,
#   'x_pressure': 98341.4453125,
#   'x_landuse': 'cropland_rainfed_herbaceous_cover',
#   'x_soilmoisture': 0.256915807723999,
#   'x_dewpoint': 283.6637268066406,
#   'x_wind': 3.606424365284706},
#  ...]

# %%
df.describe()
# Out:
#            latitude     longitude    confidence    x_dewpoint           frp  \
# count  27909.000000  27909.000000  27909.000000  26721.000000  27909.000000
# mean      45.427622     31.272562      6.884410    282.921571     13.747619
# std        6.819238     15.490044     19.070728      6.589350     45.603203
# min       33.516620     -9.480550      0.000000    253.640305      0.000000
# 25%       39.103340     21.174010      1.000000    278.823090      3.000000
# 50%       45.549840     35.826820      1.000000    283.236084      4.900000
# 75%       50.431940     43.262970      1.000000    287.722687     10.300000
# max       71.309490     57.310520    100.000000    298.551880   2504.200000
#
#              x_temp     x_pressure  x_soilmoisture        x_wind
# count  26721.000000   26721.000000    23601.000000  26721.000000
# mean      26.053819   98232.194375        0.195803      2.494185
# std        7.690084    4388.646138        0.062140      1.381792
# min      -11.332648   74532.617188        0.024804      0.022836
# 25%       21.904352   97530.710938        0.147006      1.600344
# 50%       27.077356   99787.710938        0.192210      2.285256
# 75%       31.259698  100819.125000        0.240391      3.083974
# max       47.683466  104997.843750        0.427028     12.707338

# %%
df.x_landuse.unique()
# Out:
# array(['190', '210', 'mosaic_tree_and_shrub', '130',
#        'cropland_rainfed_herbaceous_cover', '180', '150',
#        'mosaic_cropland', 'cropland_irrigated', 'cropland_rainfed',
#        'tree_needleleaved_evergreen_closed_to_open', 'mosaic_herbaceous',
#        'tree_broadleaved_deciduous_closed_to_open',
#        'mosaic_natural_vegetation', '200',
#        'tree_needleleaved_deciduous_closed_to_open',
#        'tree_broadleaved_deciduous_closed', 'tree_mixed', '160',
#        'cropland_rainfed_tree_or_shrub_cover', 'shrubland', '152',
#        'shrubland_deciduous', '153', '201', '202'], dtype=object)
